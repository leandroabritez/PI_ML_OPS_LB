# %%
import pandas as pd
import ast

# Ruta al archivo que contiene el JSON
ruta_archivo = '../PI_ML_OPS_data util/australian_users_items.json'

lista_objetos_json = []

with open(ruta_archivo, "r", encoding="utf-8") as file:
    for line in file:
        lista_objetos_json.append(ast.literal_eval(line))


# Convierte la lista de objetos a un DataFrame de Pandas para mejor lectura
data = pd.DataFrame(lista_objetos_json)

# Mostrar los primeros registros del DataFrame
print(data.head())
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
# Eliminar filas con valores NaN
# Solo aquellas que tengan toda la fila vacía
data_cleaned = data.dropna(how='all')

# Mostrar los primeros registros para verificar la lectura
print(data_cleaned.head())
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
# Reviso cantidad de nulos iniciales
print(data.isna().sum())
# Out:
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# items          0
# dtype: int64

# %%
# Reviso cantidad de nulos luego de dropna
print(data_cleaned.isna().sum())
# Out:
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# items          0
# dtype: int64

# %%
# Obtengo la composición actual del dataframe
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
data_cleaned
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 2                 http://steamcommunity.com/id/evcentric
# 3                http://steamcommunity.com/id/Riot-Punch
# 4                     http://steamcommunity.com/id/doctr
# ...                                                  ...
# 88305  http://steamcommunity.com/profiles/76561198323...
# 88306  http://steamcommunity.com/profiles/76561198326...
# 88307  http://steamcommunity.com/id/XxLaughingJackClo...
# 88308  http://steamcommunity.com/profiles/76561198329...
# 88309     http://steamcommunity.com/id/edward_tremethick
#
#                                                    items
# 0      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2      [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4      [{'item_id': '300', 'item_name': 'Day of Defea...
# ...                                                  ...
# 88305  [{'item_id': '413850', 'item_name': 'CS:GO Pla...
# 88306  [{'item_id': '11020', 'item_name': 'TrackMania...
# 88307                                                 []
# 88308  [{'item_id': '304930', 'item_name': 'Unturned'...
# 88309                                                 []
#
# [88310 rows x 5 columns]

# %%
# Borrar la columnas que no usaré
data_cleaned.drop('items_count', axis=1, inplace=True)
data_cleaned.drop('steam_id', axis=1, inplace=True)
data_cleaned.drop('user_url', axis=1, inplace=True)

# %%
data_cleaned_2 = data_cleaned[0:100]

# %%
import pandas as pd
from pandas import json_normalize

# Normalizar la columna 'items' en nuevas columnas
normalized_items = json_normalize(data_cleaned_2['items'])

# Concatenar las nuevas columnas al DataFrame original
data_cleaned_2 = pd.concat([data_cleaned_2, normalized_items], axis=1)

# Eliminar la columna 'items' original si es necesario
data_cleaned_2 = data_cleaned_2.drop('items', axis=1)

# Mostrar el DataFrame resultante
print(data_cleaned_2)
# Out:
#               user_id                                                  0  \
# 0   76561197970982479  {'item_id': '10', 'item_name': 'Counter-Strike...
# 1             js41637  {'item_id': '10', 'item_name': 'Counter-Strike...
# 2           evcentric  {'item_id': '1200', 'item_name': 'Red Orchestr...
# 3          Riot-Punch  {'item_id': '10', 'item_name': 'Counter-Strike...
# 4               doctr  {'item_id': '300', 'item_name': 'Day of Defeat...
# ..                ...                                                ...
# 95         firefreddy  {'item_id': '220', 'item_name': 'Half-Life 2',...
# 96           UTNerd24  {'item_id': '10', 'item_name': 'Counter-Strike...
# 97        sandwiches1  {'item_id': '2400', 'item_name': 'The Ship', '...
# 98  76561198093083895  {'item_id': '620', 'item_name': 'Portal 2', 'p...
# 99  76561198138053270  {'item_id': '4000', 'item_name': 'Garry's Mod'...
#
#                                                     1  \
# 0   {'item_id': '20', 'item_name': 'Team Fortress ...
# 1   {'item_id': '80', 'item_name': 'Counter-Strike...
# 2   {'item_id': '1230', 'item_name': 'Mare Nostrum...
# 3   {'item_id': '20', 'item_name': 'Team Fortress ...
# 4   {'item_id': '20', 'item_name': 'Team Fortress ...
# ..                                                ...
# 95  {'item_id': '340', 'item_name': 'Half-Life 2: ...
# 96  {'item_id': '80', 'item_name': 'Counter-Strike...
# 97  {'item_id': '2420', 'item_name': 'The Ship Sin...
# 98  {'item_id': '99900', 'item_name': 'Spiral Knig...
# 99  {'item_id': '6060', 'item_name': 'STAR WARS™ B...
#
#                                                     2  \
# 0   {'item_id': '30', 'item_name': 'Day of Defeat'...
# 1   {'item_id': '100', 'item_name': 'Counter-Strik...
# 2   {'item_id': '1280', 'item_name': 'Darkest Hour...
# 3   {'item_id': '30', 'item_name': 'Day of Defeat'...
# 4   {'item_id': '50', 'item_name': 'Half-Life: Opp...
# ..                                                ...
# 95  {'item_id': '205790', 'item_name': 'Dota 2 Tes...
# 96  {'item_id': '100', 'item_name': 'Counter-Strik...
# 97  {'item_id': '2430', 'item_name': 'The Ship Tut...
# 98  {'item_id': '265630', 'item_name': 'Fistful of...
# 99  {'item_id': '8190', 'item_name': 'Just Cause 2...
#
#                                                     3  \
# 0   {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 1   {'item_id': '300', 'item_name': 'Day of Defeat...
# 2   {'item_id': '1520', 'item_name': 'DEFCON', 'pl...
# 3   {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 4   {'item_id': '70', 'item_name': 'Half-Life', 'p...
# ..                                                ...
# 95  {'item_id': '38830', 'item_name': 'CrimeCraft ...
# 96  {'item_id': '300', 'item_name': 'Day of Defeat...
# 97  {'item_id': '3320', 'item_name': 'Insaniquariu...
# 98  {'item_id': '301520', 'item_name': 'Robocraft'...
# 99  {'item_id': '400', 'item_name': 'Portal', 'pla...
#
#                                                     4  \
# 0   {'item_id': '50', 'item_name': 'Half-Life: Opp...
# 1   {'item_id': '30', 'item_name': 'Day of Defeat'...
# 2   {'item_id': '220', 'item_name': 'Half-Life 2',...
# 3   {'item_id': '50', 'item_name': 'Half-Life: Opp...
# 4   {'item_id': '130', 'item_name': 'Half-Life: Bl...
# ..                                                ...
# 95  {'item_id': '99900', 'item_name': 'Spiral Knig...
# 96  {'item_id': '1300', 'item_name': 'SiN Episodes...
# 97  {'item_id': '240', 'item_name': 'Counter-Strik...
# 98  {'item_id': '302830', 'item_name': 'BLOCKADE 3...
# 99  {'item_id': '620', 'item_name': 'Portal 2', 'p...
#
#                                                     5  \
# 0   {'item_id': '60', 'item_name': 'Ricochet', 'pl...
# 1   {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 2   {'item_id': '320', 'item_name': 'Half-Life 2: ...
# 3   {'item_id': '60', 'item_name': 'Ricochet', 'pl...
# 4   {'item_id': '10', 'item_name': 'Counter-Strike...
# ..                                                ...
# 95  {'item_id': '104700', 'item_name': 'Super Mond...
# 96  {'item_id': '1309', 'item_name': 'SiN Multipla...
# 97  {'item_id': '4000', 'item_name': 'Garry's Mod'...
# 98  {'item_id': '304050', 'item_name': 'Trove', 'p...
# 99  {'item_id': '24240', 'item_name': 'PAYDAY: The...
#
#                                                     6  \
# 0   {'item_id': '70', 'item_name': 'Half-Life', 'p...
# 1   {'item_id': '60', 'item_name': 'Ricochet', 'pl...
# 2   {'item_id': '340', 'item_name': 'Half-Life 2: ...
# 3   {'item_id': '70', 'item_name': 'Half-Life', 'p...
# 4   {'item_id': '30', 'item_name': 'Day of Defeat'...
# ..                                                ...
# 95  {'item_id': '230410', 'item_name': 'Warframe',...
# 96  {'item_id': '1313', 'item_name': 'SiN', 'playt...
# 97  {'item_id': '8000', 'item_name': 'Tomb Raider:...
# 98  {'item_id': '304930', 'item_name': 'Unturned',...
# 99  {'item_id': '1250', 'item_name': 'Killing Floo...
#
#                                                     7  \
# 0   {'item_id': '130', 'item_name': 'Half-Life: Bl...
# 1   {'item_id': '240', 'item_name': 'Counter-Strik...
# 2   {'item_id': '360', 'item_name': 'Half-Life Dea...
# 3   {'item_id': '130', 'item_name': 'Half-Life: Bl...
# 4   {'item_id': '40', 'item_name': 'Deathmatch Cla...
# ..                                                ...
# 95  {'item_id': '286080', 'item_name': 'Thinking w...
# 96  {'item_id': '3390', 'item_name': 'Feeding Fren...
# 97  {'item_id': '4560', 'item_name': 'Company of H...
# 98  {'item_id': '317400', 'item_name': 'Portal Sto...
# 99  {'item_id': '35420', 'item_name': 'Killing Flo...
#
#                                                     8  ...  \
# 0   {'item_id': '300', 'item_name': 'Day of Defeat...  ...
# 1   {'item_id': '280', 'item_name': 'Half-Life: So...  ...
# 2   {'item_id': '380', 'item_name': 'Half-Life 2: ...  ...
# 3   {'item_id': '80', 'item_name': 'Counter-Strike...  ...
# 4   {'item_id': '60', 'item_name': 'Ricochet', 'pl...  ...
# ..                                                ...  ...
# 95  {'item_id': '265630', 'item_name': 'Fistful of...  ...
# 96  {'item_id': '240', 'item_name': 'Counter-Strik...  ...
# 97  {'item_id': '228200', 'item_name': 'Company of...  ...
# 98  {'item_id': '205790', 'item_name': 'Dota 2 Tes...  ...
# 99  {'item_id': '219640', 'item_name': 'Chivalry: ...  ...
#
#                                                   878  \
# 0                                                None
# 1   {'item_id': '463210', 'item_name': 'State of A...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   879  \
# 0                                                None
# 1   {'item_id': '463220', 'item_name': 'Dungeon of...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   880  \
# 0                                                None
# 1   {'item_id': '463350', 'item_name': 'Storm of S...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   881  \
# 0                                                None
# 1   {'item_id': '466840', 'item_name': 'Super Spac...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   882  \
# 0                                                None
# 1   {'item_id': '469730', 'item_name': 'Super Mega...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   883  \
# 0                                                None
# 1   {'item_id': '473450', 'item_name': 'The Narrat...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   884  \
# 0                                                None
# 1   {'item_id': '485330', 'item_name': 'Star Drift...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   885  \
# 0                                                None
# 1   {'item_id': '485890', 'item_name': 'Summer Sal...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   886  \
# 0                                                None
# 1   {'item_id': '491330', 'item_name': '12 Labours...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                   887
# 0                                                None
# 1   {'item_id': '397060', 'item_name': 'Faeria', '...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
# [100 rows x 889 columns]

# %%
data_cleaned_2.at[0,1]
# Out:
# {'item_id': '20',
#  'item_name': 'Team Fortress Classic',
#  'playtime_forever': 0,
#  'playtime_2weeks': 0}

# %%
# Guardar el DataFrame modificado en un archivo CSV
data_cleaned.to_csv('../PI_ML_OPS_data util/user_items.csv', index=False)
